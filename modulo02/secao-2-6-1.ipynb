# %% [markdown]
# # Interação ocm o Usuário
# ### Função Input()

# %%
print("digite sua idade:")
idade= input()
print("Você tem" , idade , "anos.")
# Out:
# digite sua idade:
# Você tem 19 anos.

# %%
idade= input("Digite sua idade: ") #fazer desta forma reduz uma linha de código print
print("Você tem", idade, "anos.")
print(type(idade)) #verifica o tipo da variável idade
# Out:
# Você tem 19 anos.
# <class 'str'>

# %%
#isso não será possível fazer
idade = int(input("Digite sua idade: ")) #se nao converter, da erro abaixo
ano_nascimento = 2025 - idade 
print("Você nasceu em ", str(ano_nascimento) ,".",sep="") #convertendo o ano para string
# Out:
# Você nasceu em 2006.

# %%
#desenvolver um programa para solicitar o valor de uma temperatura em graus celcius e converter para fahrenheit
#F = C * 9/5 + 32
temp_celcius = float(input("Digite a temperatura em graus celcius: "))
temp_fahrenheit = temp_celcius * 9/5 + 32
print("A temperatura em graus fahrenheit é: ", temp_fahrenheit , "°F", sep="") #numeros quebrados precisam sem feitos com . não com ,
# Out:
# A temperatura em graus fahrenheit é: 66.2°F

# %% [markdown]
# # Laboratório 2.6.10

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
x = float(input("Digite o valor para x: "))

# Escreva seu código aqui.
y = 1/ (x + 1/ (x + 1/ (x + 1/ x)))   

print("y =", y)
# Out:
# y = 0.6000000000000001

# %% [markdown]
# # Laboratório 2.6.11

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
#criar um código capaz de avaliar a hora de término de um período, dado
#como um número de minutos (pode ser arbitrariamente grande). A hora de início é 
# fornecida como um par de horas (0..23) e minutos (0..59). O resultado deve ser impresso no console
hour = int(input("Hora de início (horas): "))
mins = int(input("Hora de início (minutos): "))
dura = int(input("Duração do evento (minutos): "))

tempo_total= hour * 60 + mins + dura
hora_final = tempo_total // 60 % 24
minuto_final = tempo_total % 60
print(hora_final , minuto_final , sep=":")
#outra forma de fazer
hour = int(input("Hora de início (horas): "))
mins = int(input("Hora de início (minutos): "))
dura = int(input("Duração do evento (minutos): "))
mins = mins + dura # encontre um total de todos os minutos
hour = hour + mins // 60 # encontre um número de horas escondido em minutos e atualize a hora
mins = mins % 60 # minutos corretos para cair no intervalo (0..59)
hour = hour % 24 # horas corretas para cair no intervalo (0..23)
print(hour, ":", mins, sep='')
# Out:
# 10:40
